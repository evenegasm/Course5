# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
credit = pd.read_csv(r"C:\Users\emili\OneDrive\Documents\XTOL\Course5\Course5\default of credit card clients.csv", header =1)

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default_payment_next_month
# 0         0         0         0                           1
# 1      1000         0      2000                           1
# 2      1000      1000      5000                           0
# 3      1100      1069      1000                           0
# 4      9000       689       679                           0
#
# [5 rows x 25 columns]

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# std        9.217904      1.123802      1.197186      1.196868      1.169139
# min       21.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       28.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%       34.000000      0.000000      0.000000      0.000000      0.000000
# 75%       41.000000      0.000000      0.000000      0.000000      0.000000
# max       79.000000      8.000000      8.000000      8.000000      8.000000
#
#        ...      BILL_AMT4      BILL_AMT5      BILL_AMT6       PAY_AMT1  \
# count  ...   30000.000000   30000.000000   30000.000000   30000.000000
# mean   ...   43262.948967   40311.400967   38871.760400    5663.580500
# std    ...   64332.856134   60797.155770   59554.107537   16563.280354
# min    ... -170000.000000  -81334.000000 -339603.000000       0.000000
# 25%    ...    2326.750000    1763.000000    1256.000000    1000.000000
# 50%    ...   19052.000000   18104.500000   17071.000000    2100.000000
# 75%    ...   54506.000000   50190.500000   49198.250000    5006.000000
# max    ...  891586.000000  927171.000000  961664.000000  873552.000000
#
#            PAY_AMT2      PAY_AMT3       PAY_AMT4       PAY_AMT5  \
# count  3.000000e+04   30000.00000   30000.000000   30000.000000
# mean   5.921163e+03    5225.68150    4826.076867    4799.387633
# std    2.304087e+04   17606.96147   15666.159744   15278.305679
# min    0.000000e+00       0.00000       0.000000       0.000000
# 25%    8.330000e+02     390.00000     296.000000     252.500000
# 50%    2.009000e+03    1800.00000    1500.000000    1500.000000
# 75%    5.000000e+03    4505.00000    4013.250000    4031.500000
# max    1.684259e+06  896040.00000  621000.000000  426529.000000
#
#             PAY_AMT6  default_payment_next_month
# count   30000.000000                30000.000000
# mean     5215.502567                    0.221200
# std     17777.465775                    0.415062
# min         0.000000                    0.000000
# 25%       117.750000                    0.000000
# 50%      1500.000000                    0.000000
# 75%      4000.000000                    0.000000
# max    528666.000000                    1.000000
#
# [8 rows x 25 columns]

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
#  13  BILL_AMT2                   30000 non-null  int64
#  14  BILL_AMT3                   30000 non-null  int64
#  15  BILL_AMT4                   30000 non-null  int64
#  16  BILL_AMT5                   30000 non-null  int64
#  17  BILL_AMT6                   30000 non-null  int64
#  18  PAY_AMT1                    30000 non-null  int64
#  19  PAY_AMT2                    30000 non-null  int64
#  20  PAY_AMT3                    30000 non-null  int64
#  21  PAY_AMT4                    30000 non-null  int64
#  22  PAY_AMT5                    30000 non-null  int64
#  23  PAY_AMT6                    30000 non-null  int64
#  24  default_payment_next_month  30000 non-null  int64
# dtypes: int64(25)
# memory usage: 5.7 MB

# %%
# data transformation
credit.ID = credit.ID.astype("category")

# %%
credit.SEX = credit.SEX.astype("category")

# %%
credit.EDUCATION = credit.EDUCATION.astype("category")

# %%
credit.MARRIAGE = credit.MARRIAGE.astype("category")

# %%
credit.PAY_0 = credit.PAY_0.astype("category")

# %%
credit.PAY_2 = credit.PAY_2.astype("category")

# %%
credit.PAY_3 = credit.PAY_3.astype("category")

# %%
credit.PAY_4 = credit.PAY_4.astype("category")

# %%
credit.PAY_5 = credit.PAY_5.astype("category")

# %%
credit.PAY_6 = credit.PAY_6.astype("category")

# %%
credit.default_payment_next_month = credit.default_payment_next_month.astype("category")

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  category
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  category
#  3   EDUCATION                   30000 non-null  category
#  4   MARRIAGE                    30000 non-null  category
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  category
#  7   PAY_2                       30000 non-null  category
#  8   PAY_3                       30000 non-null  category
#  9   PAY_4                       30000 non-null  category
#  10  PAY_5                       30000 non-null  category
#  11  PAY_6                       30000 non-null  category
#  12  BILL_AMT1                   30000 non-null  int64
#  13  BILL_AMT2                   30000 non-null  int64
#  14  BILL_AMT3                   30000 non-null  int64
#  15  BILL_AMT4                   30000 non-null  int64
#  16  BILL_AMT5                   30000 non-null  int64
#  17  BILL_AMT6                   30000 non-null  int64
#  18  PAY_AMT1                    30000 non-null  int64
#  19  PAY_AMT2                    30000 non-null  int64
#  20  PAY_AMT3                    30000 non-null  int64
#  21  PAY_AMT4                    30000 non-null  int64
#  22  PAY_AMT5                    30000 non-null  int64
#  23  PAY_AMT6                    30000 non-null  int64
#  24  default_payment_next_month  30000 non-null  category
# dtypes: category(11), int64(14)
# memory usage: 4.8 MB

# %%
credit.describe()
# Out:
#             LIMIT_BAL           AGE      BILL_AMT1      BILL_AMT2  \
# count    30000.000000  30000.000000   30000.000000   30000.000000
# mean    167484.322667     35.485500   51223.330900   49179.075167
# std     129747.661567      9.217904   73635.860576   71173.768783
# min      10000.000000     21.000000 -165580.000000  -69777.000000
# 25%      50000.000000     28.000000    3558.750000    2984.750000
# 50%     140000.000000     34.000000   22381.500000   21200.000000
# 75%     240000.000000     41.000000   67091.000000   64006.250000
# max    1000000.000000     79.000000  964511.000000  983931.000000
#
#           BILL_AMT3      BILL_AMT4      BILL_AMT5      BILL_AMT6  \
# count  3.000000e+04   30000.000000   30000.000000   30000.000000
# mean   4.701315e+04   43262.948967   40311.400967   38871.760400
# std    6.934939e+04   64332.856134   60797.155770   59554.107537
# min   -1.572640e+05 -170000.000000  -81334.000000 -339603.000000
# 25%    2.666250e+03    2326.750000    1763.000000    1256.000000
# 50%    2.008850e+04   19052.000000   18104.500000   17071.000000
# 75%    6.016475e+04   54506.000000   50190.500000   49198.250000
# max    1.664089e+06  891586.000000  927171.000000  961664.000000
#
#             PAY_AMT1      PAY_AMT2      PAY_AMT3       PAY_AMT4  \
# count   30000.000000  3.000000e+04   30000.00000   30000.000000
# mean     5663.580500  5.921163e+03    5225.68150    4826.076867
# std     16563.280354  2.304087e+04   17606.96147   15666.159744
# min         0.000000  0.000000e+00       0.00000       0.000000
# 25%      1000.000000  8.330000e+02     390.00000     296.000000
# 50%      2100.000000  2.009000e+03    1800.00000    1500.000000
# 75%      5006.000000  5.000000e+03    4505.00000    4013.250000
# max    873552.000000  1.684259e+06  896040.00000  621000.000000
#
#             PAY_AMT5       PAY_AMT6
# count   30000.000000   30000.000000
# mean     4799.387633    5215.502567
# std     15278.305679   17777.465775
# min         0.000000       0.000000
# 25%       252.500000     117.750000
# 50%      1500.000000    1500.000000
# 75%      4031.500000    4000.000000
# max    426529.000000  528666.000000

# %%
#check for missing values
print(credit.isnull().sum())
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default_payment_next_month    0
# dtype: int64

# %%
#Replacing Education values to OTHER (simplification)
credit.EDUCATION = credit.EDUCATION.map({0 : 0, 3 : 3, 2 : 2, 1 : 1, 4 : 0, 5 : 0, 6 : 0})
credit.EDUCATION = credit.EDUCATION.astype("category")

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  category
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  category
#  3   EDUCATION                   30000 non-null  category
#  4   MARRIAGE                    30000 non-null  category
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  category
#  7   PAY_2                       30000 non-null  category
#  8   PAY_3                       30000 non-null  category
#  9   PAY_4                       30000 non-null  category
#  10  PAY_5                       30000 non-null  category
#  11  PAY_6                       30000 non-null  category
#  12  BILL_AMT1                   30000 non-null  int64
#  13  BILL_AMT2                   30000 non-null  int64
#  14  BILL_AMT3                   30000 non-null  int64
#  15  BILL_AMT4                   30000 non-null  int64
#  16  BILL_AMT5                   30000 non-null  int64
#  17  BILL_AMT6                   30000 non-null  int64
#  18  PAY_AMT1                    30000 non-null  int64
#  19  PAY_AMT2                    30000 non-null  int64
#  20  PAY_AMT3                    30000 non-null  int64
#  21  PAY_AMT4                    30000 non-null  int64
#  22  PAY_AMT5                    30000 non-null  int64
#  23  PAY_AMT6                    30000 non-null  int64
#  24  default_payment_next_month  30000 non-null  category
# dtypes: category(11), int64(14)
# memory usage: 4.8 MB

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default_payment_next_month'],
#       dtype='object')

# %%
plt.hist(credit['LIMIT_BAL'], bins=6)
plt.show()

# %%
plt.hist(credit['SEX'])
plt.show()

# %%
plt.hist(credit['EDUCATION'])
plt.show()

# %%
plt.hist(credit['MARRIAGE'])
plt.show()

# %%
# create a binning for age
bin_labels = ['20-28', '28-34', '34-41', '41-79']
credit["CAT_AGE"] = pd.qcut(credit["AGE"], 4,  labels=bin_labels)

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default_payment_next_month', 'CAT_AGE'],
#       dtype='object')

# %%
# Grouping age counts for easy viewing
xc = sns.catplot('CAT_AGE', data=credit, kind='count', aspect=1.5)
xc.set_xlabels('AGE')
print(credit.groupby("CAT_AGE").size())
# Out:
# CAT_AGE
# 20-28    8013
# 28-34    7683
# 34-41    6854
# 41-79    7450
# dtype: int64

# %%
plt.plot(credit['LIMIT_BAL'])
plt.show()

# %%
#using mix scatter
x = credit['PAY_0']
y = credit['PAY_2']
plt.scatter(x,y)
plt.show()

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default_payment_next_month', 'CAT_AGE'],
#       dtype='object')

# %%
# box plot
A = credit['BILL_AMT1']
plt.boxplot(A,0,'gD')
plt.show()

# %%
# correlation matrix
corrMat = credit.corr()
print(corrMat)
# Out:
#            LIMIT_BAL       AGE  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  \
# LIMIT_BAL   1.000000  0.144713   0.285430   0.278314   0.283236   0.293988
# AGE         0.144713  1.000000   0.056239   0.054283   0.053710   0.051353
# BILL_AMT1   0.285430  0.056239   1.000000   0.951484   0.892279   0.860272
# BILL_AMT2   0.278314  0.054283   0.951484   1.000000   0.928326   0.892482
# BILL_AMT3   0.283236  0.053710   0.892279   0.928326   1.000000   0.923969
# BILL_AMT4   0.293988  0.051353   0.860272   0.892482   0.923969   1.000000
# BILL_AMT5   0.295562  0.049345   0.829779   0.859778   0.883910   0.940134
# BILL_AMT6   0.290389  0.047613   0.802650   0.831594   0.853320   0.900941
# PAY_AMT1    0.195236  0.026147   0.140277   0.280365   0.244335   0.233012
# PAY_AMT2    0.178408  0.021785   0.099355   0.100851   0.316936   0.207564
# PAY_AMT3    0.210167  0.029247   0.156887   0.150718   0.130011   0.300023
# PAY_AMT4    0.203242  0.021379   0.158303   0.147398   0.143405   0.130191
# PAY_AMT5    0.217202  0.022850   0.167026   0.157957   0.179712   0.160433
# PAY_AMT6    0.219595  0.019478   0.179341   0.174256   0.182326   0.177637
#
#            BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  \
# LIMIT_BAL   0.295562   0.290389  0.195236  0.178408  0.210167  0.203242
# AGE         0.049345   0.047613  0.026147  0.021785  0.029247  0.021379
# BILL_AMT1   0.829779   0.802650  0.140277  0.099355  0.156887  0.158303
# BILL_AMT2   0.859778   0.831594  0.280365  0.100851  0.150718  0.147398
# BILL_AMT3   0.883910   0.853320  0.244335  0.316936  0.130011  0.143405
# BILL_AMT4   0.940134   0.900941  0.233012  0.207564  0.300023  0.130191
# BILL_AMT5   1.000000   0.946197  0.217031  0.181246  0.252305  0.293118
# BILL_AMT6   0.946197   1.000000  0.199965  0.172663  0.233770  0.250237
# PAY_AMT1    0.217031   0.199965  1.000000  0.285576  0.252191  0.199558
# PAY_AMT2    0.181246   0.172663  0.285576  1.000000  0.244770  0.180107
# PAY_AMT3    0.252305   0.233770  0.252191  0.244770  1.000000  0.216325
# PAY_AMT4    0.293118   0.250237  0.199558  0.180107  0.216325  1.000000
# PAY_AMT5    0.141574   0.307729  0.148459  0.180908  0.159214  0.151830
# PAY_AMT6    0.164184   0.115494  0.185735  0.157634  0.162740  0.157834
#
#            PAY_AMT5  PAY_AMT6
# LIMIT_BAL  0.217202  0.219595
# AGE        0.022850  0.019478
# BILL_AMT1  0.167026  0.179341
# BILL_AMT2  0.157957  0.174256
# BILL_AMT3  0.179712  0.182326
# BILL_AMT4  0.160433  0.177637
# BILL_AMT5  0.141574  0.164184
# BILL_AMT6  0.307729  0.115494
# PAY_AMT1   0.148459  0.185735
# PAY_AMT2   0.180908  0.157634
# PAY_AMT3   0.159214  0.162740
# PAY_AMT4   0.151830  0.157834
# PAY_AMT5   1.000000  0.154896
# PAY_AMT6   0.154896  1.000000

# %%
corrMat.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row0_col1 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row0_col2 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row0_col3 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row0_col4 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row0_col5 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row0_col6 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row0_col7 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row0_col8 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row0_col9 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row0_col10 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row0_col11 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row0_col12 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row0_col13 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row1_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row1_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row1_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row1_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row1_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row1_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row1_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row2_col0 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row2_col1 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row2_col3 {
#             background-color:  #c73635;
#             color:  #f1f1f1;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row2_col4 {
#             background-color:  #da5a49;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row2_col5 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row2_col6 {
#             background-color:  #e97a5f;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row2_col7 {
#             background-color:  #ef886b;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row2_col8 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row2_col9 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row2_col10 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row2_col11 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row2_col12 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row2_col13 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row3_col0 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row3_col1 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row3_col2 {
#             background-color:  #c73635;
#             color:  #f1f1f1;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row3_col4 {
#             background-color:  #cf453c;
#             color:  #f1f1f1;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row3_col5 {
#             background-color:  #da5a49;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row3_col6 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row3_col7 {
#             background-color:  #e97a5f;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row3_col8 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row3_col9 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row3_col10 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row3_col11 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row3_col12 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row3_col13 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row4_col0 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row4_col1 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row4_col2 {
#             background-color:  #da5a49;
#             color:  #000000;
#         }    #T_0c7b4ceb_6a5d_11ea_bbe3_ed74aecbb4f4row4_col3 {
#             background-color:  #cf453c;
#             colo

# %%
# covariance matrix
covMat = credit.cov()
print(covMat)
# Out:
#               LIMIT_BAL            AGE     BILL_AMT1     BILL_AMT2  \
# LIMIT_BAL  1.683446e+10  173076.722569  2.727020e+09  2.570130e+09
# AGE        1.730767e+05      84.969755  3.817293e+04  3.561366e+04
# BILL_AMT1  2.727020e+09   38172.933546  5.422240e+09  4.986670e+09
# BILL_AMT2  2.570130e+09   35613.657962  4.986670e+09  5.065705e+09
# BILL_AMT3  2.548533e+09   34334.251320  4.556511e+09  4.582086e+09
# BILL_AMT4  2.453926e+09   30453.108180  4.075286e+09  4.086508e+09
# BILL_AMT5  2.331481e+09   27654.067800  3.714795e+09  3.720401e+09
# BILL_AMT6  2.243837e+09   26137.648547  3.519876e+09  3.524868e+09
# PAY_AMT1   4.195711e+08    3992.041735  1.710894e+08  3.305146e+08
# PAY_AMT2   5.333504e+08    4626.861549  1.685692e+08  1.653859e+08
# PAY_AMT3   4.801180e+08    4746.824393  2.034048e+08  1.888731e+08
# PAY_AMT4   4.131202e+08    3087.324192  1.826164e+08  1.643518e+08
# PAY_AMT5   4.305657e+08    3218.052172  1.879091e+08  1.717652e+08
# PAY_AMT6   5.065153e+08    3191.903901  2.347681e+08  2.204845e+08
#
#               BILL_AMT3     BILL_AMT4     BILL_AMT5     BILL_AMT6  \
# LIMIT_BAL  2.548533e+09  2.453926e+09  2.331481e+09  2.243837e+09
# AGE        3.433425e+04  3.045311e+04  2.765407e+04  2.613765e+04
# BILL_AMT1  4.556511e+09  4.075286e+09  3.714795e+09  3.519876e+09
# BILL_AMT2  4.582086e+09  4.086508e+09  3.720401e+09  3.524868e+09
# BILL_AMT3  4.809338e+09  4.122238e+09  3.726780e+09  3.524247e+09
# BILL_AMT4  4.122238e+09  4.138716e+09  3.677105e+09  3.451762e+09
# BILL_AMT5  3.726780e+09  3.677105e+09  3.696294e+09  3.425914e+09
# BILL_AMT6  3.524247e+09  3.451762e+09  3.425914e+09  3.546692e+09
# PAY_AMT1   2.806565e+08  2.482888e+08  2.185501e+08  1.972478e+08
# PAY_AMT2   5.064226e+08  3.076686e+08  2.538936e+08  2.369244e+08
# PAY_AMT3   1.587478e+08  3.398374e+08  2.700805e+08  2.451233e+08
# PAY_AMT4   1.558003e+08  1.312133e+08  2.791830e+08  2.334670e+08
# PAY_AMT5   1.904126e+08  1.576892e+08  1.315051e+08  2.799982e+08
# PAY_AMT6   2.247817e+08  2.031590e+08  1.774537e+08  1.222761e+08
#
#                PAY_AMT1      PAY_AMT2      PAY_AMT3      PAY_AMT4  \
# LIMIT_BAL  4.195711e+08  5.333504e+08  4.801180e+08  4.131202e+08
# AGE        3.992042e+03  4.626862e+03  4.746824e+03  3.087324e+03
# BILL_AMT1  1.710894e+08  1.685692e+08  2.034048e+08  1.826164e+08
# BILL_AMT2  3.305146e+08  1.653859e+08  1.888731e+08  1.643518e+08
# BILL_AMT3  2.806565e+08  5.064226e+08  1.587478e+08  1.558003e+08
# BILL_AMT4  2.482888e+08  3.076686e+08  3.398374e+08  1.312133e+08
# BILL_AMT5  2.185501e+08  2.538936e+08  2.700805e+08  2.791830e+08
# BILL_AMT6  1.972478e+08  2.369244e+08  2.451233e+08  2.334670e+08
# PAY_AMT1   2.743423e+08  1.089849e+08  7.354626e+07  5.178189e+07
# PAY_AMT2   1.089849e+08  5.308817e+08  9.929841e+07  6.501168e+07
# PAY_AMT3   7.354626e+07  9.929841e+07  3.100051e+08  5.966970e+07
# PAY_AMT4   5.178189e+07  6.501168e+07  5.966970e+07  2.454286e+08
# PAY_AMT5   3.756893e+07  6.368414e+07  4.282921e+07  3.634098e+07
# PAY_AMT6   5.469033e+07  6.456816e+07  5.093879e+07  4.395747e+07
#
#                PAY_AMT5      PAY_AMT6
# LIMIT_BAL  4.305657e+08  5.065153e+08
# AGE        3.218052e+03  3.191904e+03
# BILL_AMT1  1.879091e+08  2.347681e+08
# BILL_AMT2  1.717652e+08  2.204845e+08
# BILL_AMT3  1.904126e+08  2.247817e+08
# BILL_AMT4  1.576892e+08  2.031590e+08
# BILL_AMT5  1.315051e+08  1.774537e+08
# BILL_AMT6  2.799982e+08  1.222761e+08
# PAY_AMT1   3.756893e+07  5.469033e+07
# PAY_AMT2   6.368414e+07  6.456816e+07
# PAY_AMT3   4.282921e+07  5.093879e+07
# PAY_AMT4   3.634098e+07  4.395747e+07
# PAY_AMT5   2.334266e+08  4.207110e+07
# PAY_AMT6   4.207110e+07  3.160383e+08

# %%
covMat.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row0_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row0_col2 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row0_col3 {
#             background-color:  #dedcdb;
#             color:  #000000;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row0_col4 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row0_col5 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row0_col6 {
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row0_col7 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row0_col8 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row0_col9 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row0_col10 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row0_col11 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row0_col12 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row0_col13 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row1_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row1_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row1_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row1_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row1_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row1_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row1_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row1_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row2_col0 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row2_col1 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row2_col3 {
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row2_col4 {
#             background-color:  #c73635;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row2_col5 {
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row2_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row2_col7 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row2_col8 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row2_col9 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row2_col10 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row2_col11 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row2_col12 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row2_col13 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row3_col0 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row3_col1 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row3_col2 {
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row3_col4 {
#             background-color:  #c53334;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row3_col5 {
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row3_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row3_col7 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row3_col8 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row3_col9 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row3_col10 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row3_col11 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row3_col12 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row3_col13 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row4_col0 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row4_col1 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row4_col2 {
#             background-color:  #e57058;
#             color:  #000000;
#         }    #T_0c9475e5_6a5d_11ea_b798_ed74aecbb4f4row4_col3 {
#             background-color:  #d55042;
#             colo

# %%
credit.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default_payment_next_month', 'CAT_AGE'],
#       dtype='object')

# %%
# Count by SEX / 1=male, 2=female
credit.groupby('SEX')['SEX'].count()
# Out:
# SEX
# 1    11888
# 2    18112
# Name: SEX, dtype: int64

# %%
# Count by MARRIAGE / 1 = married; 2 = single; 3 = divorce; 0=others
credit.groupby('MARRIAGE')['MARRIAGE'].count()
# Out:
# MARRIAGE
# 0       54
# 1    13659
# 2    15964
# 3      323
# Name: MARRIAGE, dtype: int64

# %%
# MARRIAGE graph
fg = sns.catplot('MARRIAGE', data=credit, kind='count', aspect=1.5)
fg.set_xlabels('STATUS')
print(credit.groupby("MARRIAGE").size())
# Out:
# MARRIAGE
# 0       54
# 1    13659
# 2    15964
# 3      323
# dtype: int64

# %%
# Sex and Marriage relation
x = credit['MARRIAGE']
y = credit['SEX']
plt.scatter(x,y)
plt.show()

# %%
# age count by age_category - by sex
t = sns.factorplot('CAT_AGE', data=credit, hue='SEX', kind='count', aspect=1.75)
t.set_xlabels('AGE')
credit.groupby(['SEX', 'CAT_AGE'])['SEX'].count()
# Out:
# c:\users\emili\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# SEX  CAT_AGE
# 1    20-28      2664
#      28-34      3051
#      34-41      2843
#      41-79      3330
# 2    20-28      5349
#      28-34      4632
#      34-41      4011
#      41-79      4120
# Name: SEX, dtype: int64

# %%
# graph default payment - totals 
credit['default_payment_next_month'].value_counts().plot(kind='bar')

# %%
# previous amount from month 6 by age and sex 
credit.pivot_table('PAY_AMT6', 'SEX', 'CAT_AGE', aggfunc=np.sum, margins=True)
# Out:
# CAT_AGE     20-28     28-34     34-41     41-79        All
# SEX
# 1         9991337  19141723  15863627  17726740   62723427
# 2        20940121  28755471  22192079  21853979   93741650
# All      30931458  47897194  38055706  39580719  156465077

# %%
# default payment by age_category
g = sns.catplot('CAT_AGE', data=credit, hue='default_payment_next_month', kind='count', aspect=1.75)
g.set_xlabels('CAT_AGE')

# %%
# default payment by sex
g = sns.catplot('SEX', data=credit, hue='default_payment_next_month', kind='count', aspect=1.75)
g.set_xlabels('SEX')

# %%
# amount of previos payment(month1) by sex and default payment
credit.pivot_table('PAY_AMT1', 'SEX', 'default_payment_next_month', aggfunc=len, margins=True)
# Out:
# default_payment_next_month      0     1    All
# SEX
# 1                            9015  2873  11888
# 2                           14349  3763  18112
# All                         23364  6636  30000

# %%
# amount of previos payment(month1) by marriage and default payment
credit.pivot_table('PAY_AMT1', 'MARRIAGE', 'default_payment_next_month', aggfunc=len, margins=True)
# Out:
# default_payment_next_month      0     1    All
# MARRIAGE
# 0                              49     5     54
# 1                           10453  3206  13659
# 2                           12623  3341  15964
# 3                             239    84    323
# All                         23364  6636  30000

# %%
# crosstable to analyze the history of payment2 by education and default payment
table = pd.crosstab(index=[credit.PAY_2, credit.EDUCATION], columns=[credit.default_payment_next_month])
table.unstack()
# Out:
# default_payment_next_month      0                             1         \
# EDUCATION                       0       1       2       3     0      1
# PAY_2
# -2                           79.0  1549.0  1093.0   370.0   4.0  349.0
# -1                           79.0  2502.0  1828.0   675.0   1.0  449.0
#  0                          262.0  3988.0  6736.0  2241.0  26.0  596.0
#  1                            NaN     6.0    15.0     2.0   NaN    2.0
#  2                           14.0   466.0   916.0   347.0   2.0  586.0
#  3                            NaN    29.0    66.0    30.0   NaN   41.0
#  4                            1.0     8.0    33.0     7.0   0.0    6.0
#  5                            NaN     1.0     5.0     4.0   NaN    2.0
#  6                            NaN     0.0     2.0     1.0   NaN    1.0
#  7                            NaN     0.0     6.0     2.0   NaN    4.0
#  8                            NaN     NaN     NaN     1.0   NaN    NaN
#
# default_payment_next_month
# EDUCATION                        2      3
# PAY_2
# -2                           241.0   97.0
# -1                           362.0  154.0
#  0                          1399.0  482.0
#  1                             3.0    0.0
#  2                          1157.0  439.0
#  3                           113.0   47.0
#  4                            32.0   12.0
#  5                            10.0    3.0
#  6                             7.0    1.0
#  7                             6.0    2.0
#  8                             NaN    0.0

# %%
table.columns, table.index
# Out:
# (CategoricalIndex([0, 1], categories=[0, 1], ordered=False, name='default_payment_next_month', dtype='category'),
#  MultiIndex([(-2, 0),
#              (-2, 1),
#              (-2, 2),
#              (-2, 3),
#              (-1, 0),
#              (-1, 1),
#              (-1, 2),
#              (-1, 3),
#              ( 0, 0),
#              ( 0, 1),
#              ( 0, 2),
#              ( 0, 3),
#              ( 1, 1),
#              ( 1, 2),
#              ( 1, 3),
#              ( 2, 0),
#              ( 2, 1),
#              ( 2, 2),
#              ( 2, 3),
#              ( 3, 1),
#              ( 3, 2),
#              ( 3, 3),
#              ( 4, 0),
#              ( 4, 1),
#              ( 4, 2),
#              ( 4, 3),
#              ( 5, 1),
#              ( 5, 2),
#              ( 5, 3),
#              ( 6, 1),
#              ( 6, 2),
#              ( 6, 3),
#              ( 7, 1),
#              ( 7, 2),
#              ( 7, 3),
#              ( 8, 3)],
#             names=['PAY_2', 'EDUCATION']))

# %%
#Limit distribution
limit_dist = sns.distplot(credit['LIMIT_BAL'])
limit_dist.set_title("Limit distribution")
# Out:
# Text(0.5, 1.0, 'Limit distribution')

# %%
#Age distribution
age_dist = sns.distplot(credit['AGE'])
age_dist.set_title("Age distribution")
# Out:
# Text(0.5, 1.0, 'Age distribution')

# %%
# crosstable to analyze the history of payment0 by sex and age category
table = pd.crosstab(index=[credit.PAY_0, credit.SEX], columns=[credit.CAT_AGE])
table.unstack()
# Out:
# CAT_AGE 20-28       28-34       34-41       41-79
# SEX         1     2     1     2     1     2     1     2
# PAY_0
# -2        122   311   236   576   253   510   260   491
# -1        376   818   582   953   537   952   637   831
#  0       1472  2931  1559  2178  1359  1745  1641  1852
#  1        351   650   394   551   362   477   385   518
#  2        276   561   232   328   273   288   339   370
#  3         45    59    32    37    38    28    44    39
#  4         14    13     7     5     9     4    14    10
#  5          4     2     4     2     5     1     5     3
#  6          2     1     1     2     1     0     2     2
#  7          0     0     2     0     1     3     2     1
#  8          2     3     2     0     5     3     1     3

# %%
# crosstable to analyze the history of payment2 by sex and age category
table = pd.crosstab(index=[credit.PAY_2, credit.SEX], columns=[credit.CAT_AGE])
table.unstack()
# Out:
# CAT_AGE   20-28           28-34           34-41           41-79
# SEX           1       2       1       2       1       2       1       2
# PAY_2
# -2        186.0   465.0   338.0   759.0   353.0   674.0   352.0   655.0
# -1        369.0   886.0   595.0  1021.0   577.0  1003.0   679.0   920.0
#  0       1608.0  3138.0  1645.0  2313.0  1461.0  1854.0  1753.0  1958.0
#  1          2.0     5.0     6.0     3.0     2.0     3.0     4.0     3.0
#  2        417.0   768.0   427.0   489.0   396.0   437.0   470.0   523.0
#  3         56.0    66.0    25.0    35.0    29.0    29.0    46.0    40.0
#  4         17.0    13.0    10.0     7.0    16.0     5.0    17.0    14.0
#  5          6.0     3.0     1.0     5.0     2.0     0.0     5.0     3.0
#  6          1.0     1.0     2.0     0.0     2.0     3.0     2.0     1.0
#  7          2.0     3.0     2.0     0.0     5.0     3.0     2.0     3.0
#  8          NaN     1.0     NaN     0.0     NaN     0.0     NaN     0.0

# %%
# quantity of default payments on september
plt.scatter(credit['default_payment_next_month'],credit['PAY_AMT6'])

# %%
plt.scatter(credit['BILL_AMT1'],credit['PAY_AMT1'])

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Basic Plot')
ax1.boxplot(credit['BILL_AMT1'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2030e958>,
#   <matplotlib.lines.Line2D at 0x2030eb08>],
#  'caps': [<matplotlib.lines.Line2D at 0x2030ecb8>,
#   <matplotlib.lines.Line2D at 0x2030ee68>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2030e7a8>],
#  'medians': [<matplotlib.lines.Line2D at 0x20319040>],
#  'fliers': [<matplotlib.lines.Line2D at 0x203191c0>],
#  'means': []}

# %%
credit.boxplot(column='LIMIT_BAL', by='CAT_AGE', rot=90)

# %%
credit.plot(kind='scatter', x='AGE', y='LIMIT_BAL', rot=70)

# %%
g = sns.catplot('EDUCATION', data=credit, hue='SEX', kind='count', aspect=1.75)
g.set_xlabels('EDUCATION')

# %%
credit['MARRIAGE'].value_counts().plot(kind='bar')

# %%
dummy = pd.get_dummies(credit['EDUCATION'])
dummy.head()
# Out:
#    0  1  2  3
# 0  0  0  1  0
# 1  0  0  1  0
# 2  0  0  1  0
# 3  0  0  1  0
# 4  0  0  1  0

# %%
fig = sns.FacetGrid(credit, hue='SEX', aspect=4)
fig.map(sns.kdeplot, 'AGE', shade=True)
oldest = credit['AGE'].max()
fig.set(xlim=(0,oldest))
fig.set(title='Distribution of Age Grouped by Gender')
fig.add_legend()

# %%
fig = sns.FacetGrid(credit, hue='default_payment_next_month', aspect=4)
fig.map(sns.kdeplot, 'AGE', shade=True)
oldest = credit['AGE'].max()
fig.set(xlim=(0,oldest))
fig.set(title='Distribution of Age Grouped by Default payment')
fig.add_legend()
